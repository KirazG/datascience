# %%
import pandas as pd
# %matplotlib inline
df_listings = df = pd.read_csv('data/listings.csv',header=0)
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44317 entries, 0 to 44316
# Data columns (total 16 columns):
# id                                44317 non-null int64
# name                              44289 non-null object
# host_id                           44317 non-null int64
# host_name                         44085 non-null object
# neighbourhood_group               44317 non-null object
# neighbourhood                     44317 non-null object
# latitude                          44317 non-null float64
# longitude                         44317 non-null float64
# room_type                         44317 non-null object
# price                             44317 non-null int64
# minimum_nights                    44317 non-null int64
# number_of_reviews                 44317 non-null int64
# last_review                       34877 non-null object
# reviews_per_month                 34843 non-null float64
# calculated_host_listings_count    44317 non-null int64
# ...

# %%
df_listings.head(10)
# Out:
#          id                                               name    host_id  \
# 0  18461891     Bright, comfortable 1B studio near everything!     916092
# 1  20702398                         Quiet house on City Island    1457680
# 2   6627449                     Large 1 BDRM in Great location   13886510
# 3  19949243                            Stay aboard  a sailboat    1149260
# 4   1886820                     Quaint City Island Community.     9815788
# 5   5557381                            Quaint City Island Home   28811542
# 6  19609887                                      Sweet Getaway  137892083
# 7   7949480  City Island Sanctuary BR & Private Bath w Parking     119445
# 8  21057372                     Relax and unwind on the water.  151702414
# 9  16042478                        WATERFRONT STUDIO APARTMENT    9117975
#
#         host_name neighbourhood_group     neighbourhood   latitude  longitude  \
# ...

# %%
df_calendar = df = pd.read_csv('data/calendar.csv',header=0)
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16182640 entries, 0 to 16182639
# Data columns (total 4 columns):
# listing_id    int64
# date          object
# available     object
# price         object
# dtypes: int64(1), object(3)
# memory usage: 493.9+ MB

# %%
df_calendar.head(10)
# Out:
#    listing_id        date available   price
# 0        2515  2018-10-01         t  $99.00
# 1        2515  2018-09-30         t  $89.00
# 2        2515  2018-09-29         t  $99.00
# 3        2515  2018-09-28         t  $99.00
# 4        2515  2018-09-27         t  $99.00
# 5        2515  2018-09-26         t  $99.00
# 6        2515  2018-09-25         t  $99.00
# 7        2515  2018-09-24         t  $99.00
# 8        2515  2018-09-23         t  $99.00
# 9        2515  2018-09-22         t  $99.00

# %%
df_reviews = df = pd.read_csv('data/reviews-detailed.csv',header=0)
df_reviews.tail(10)
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 801774    16859979  130344622  2017-02-05    114348667        Audrey
# 801775    16859979  131532477  2017-02-12     55842658       Shivani
# 801776    16859979  132891770  2017-02-19     16006875           Ana
# 801777    16859979  134221609  2017-02-26     36701279       Daniela
# 801778    16859979  134388105  2017-02-26     28926295       Akshaya
# 801779    16859979  135590128  2017-03-05     86946561         Anton
# 801780    16859979  139787326  2017-03-26    118861692          Levi
# 801781    16859979  148417751  2017-04-30     48554768        Denise
# 801782    16859979  152642145  2017-05-17    128399331          Adam
# 801783    16859979  154250044  2017-05-23     32920117        Andres
#
#                                                  comments
# 801774  Loved our stay here. Great location right near...
# 801775  Jeff's place is amazing, it is very close to t...
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801784 entries, 0 to 801783
# Data columns (total 6 columns):
# listing_id       801784 non-null int64
# id               801784 non-null int64
# date             801784 non-null object
# reviewer_id      801784 non-null int64
# reviewer_name    801784 non-null object
# comments         801007 non-null object
# dtypes: int64(3), object(3)
# memory usage: 36.7+ MB

# %%
grouped_df = df_reviews.groupby( [ "listing_id"] )
grouped_df
